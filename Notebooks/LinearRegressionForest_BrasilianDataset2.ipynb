# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
df = pd.read_csv('terrabrasilis_legal_amazon_26_4_2021_1622080569977.csv', sep=";")
df.dtypes
# Out:
# year         int64
# area km²    object
# uf          object
# dtype: object

# %%
df.head()
# Out:
#    year  area km²           uf
# 0  2020     25.00    TOCANTINS
# 1  2020    297.00      RORAIMA
# 2  2020  1,273.00     RONDÔNIA
# 3  2020  4,899.00         PARÁ
# 4  2020  1,779.00  MATO GROSSO

# %%
df
# Out:
#      year  area km²           uf
# 0    2020     25.00    TOCANTINS
# 1    2020    297.00      RORAIMA
# 2    2020  1,273.00     RONDÔNIA
# 3    2020  4,899.00         PARÁ
# 4    2020  1,779.00  MATO GROSSO
# ..    ...       ...          ...
# 292  1988  5,140.00  MATO GROSSO
# 293  1988  2,450.00     MARANHÃO
# 294  1988     60.00        AMAPÁ
# 295  1988  1,510.00     AMAZONAS
# 296  1988    620.00         ACRE
#
# [297 rows x 3 columns]

# %%
df['area km²'] = df['area km²'].str.replace(',','').astype(float).astype(int)
df.head()
# Out:
#    year  area km²           uf
# 0  2020        25    TOCANTINS
# 1  2020       297      RORAIMA
# 2  2020      1273     RONDÔNIA
# 3  2020      4899         PARÁ
# 4  2020      1779  MATO GROSSO

# %%
df = df.rename(columns={'area km²':'area'})
df.head()
# Out:
#    year  area           uf
# 0  2020    25    TOCANTINS
# 1  2020   297      RORAIMA
# 2  2020  1273     RONDÔNIA
# 3  2020  4899         PARÁ
# 4  2020  1779  MATO GROSSO

# %%
X = df.year.values.reshape(-1, 1)
y = df.area.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
X
# Out:
# Shape:  (297, 1) (297, 1)
# array([[2020],
#        [2020],
#        [2020],
#        [2020],
#        [2020],
#        [2020],
#        [2020],
#        [2020],
#        [2020],
#        [2019],
#        [2019],
#        [2019],
#        [2019],
#        [2019],
#        [2019],
#        [2019],
#        [2019],
#        [2019],
#        [2018],
#        [2018],
#        [2018],
#        [2018],
#        [2018],
#        [2018],
#        [2018],
#        [2018],
#        [2018],
#        [2017],
#        [2017],
#        [2017],
#        [2017],
#        [2017],
#        [2017],
#        [2017],
#        [2017],
#        [2017],
#        [2016],
#        [2016],
#        [2016],
#        [2016],
#        [2016],
#        [2016],
#        [2016],
#        [2016],
#        [2016],
#        [2015],
#        [2015],
#        [2015],
#        [2015],
#        [2015],
#        [2015],
#        [2015],
#        [2015],
#        [2015],
#        [2014],
#        [2014],
#        [2014],
#        [2014],
#        [2014],
#        [2014],
#        [2014],
#        [2014],
#        [2014],
#        [2013],
#        [2013],
#        [2013],
#        [2013],
#        [2013],
#        [2013],
#        [2013],
#        [2013],
#        [2013],
#        [2012],
#        [2012],
#        [2012],
#        [2012],
#        [2012],
#        [2012],
#        [2012],
#        [2012],
#        [2012],
#        [2011],
#        [2011],
#        [2011],
#        [2011],
#        [2011],
#        [2011],
#        [2011],
#        [2011],
#        [2011],
#        [2010],
#        [2010],
#        [2010],
#        [2010],
#        [2010],
#        [2010],
#        [2010],
#        [2010],
#        [2010],
#        [2009],
#        [2009],
#        [2009],
#        [2009],
#        [2009],
#        [2009],
#        [2009],
#        [2009],
#        [2009],
#        [2008],
#        [2008],
#        [2008],
#        [2008],
#        [2008],
#        [2008],
#        [2008],
#        [2008],
#        [2008],
#        [2007],
#        [2007],
#        [2007],
#        [2007],
#        [2007],
#        [2007],
#        [2007],
#        [2007],
#        [2007],
#        [2006],
#        [2006],
#        [2006],
#        [2006],
#        [2006],
#        [2006],
#        [2006],
#        [2006],
#        [2006],
#        [2005],
#        [2005],
#        [2005],
#        [2005],
#        [2005],
#        [2005],
#        [2005],
#        [2005],
#        [2005],
#        [2004],
#        [2004],
#        [2004],
#        [2004],
#        [2004],
#        [2004],
#        [2004],
#        [2004],
#        [2004],
#        [2003],
#        [2003],
#        [2003],
#        [2003],
#        [2003],
#        [2003],
#        [2003],
#        [2003],
#        [2003],
#        [2002],
#        [2002],
#        [2002],
#        [2002],
#        [2002],
#        [2002],
#        [2002],
#        [2002],
#        [2002],
#        [2001],
#        [2001],
#        [2001],
#        [2001],
#        [2001],
#        [2001],
#        [2001],
#        [2001],
#        [2001],
#        [2000],
#        [2000],
#        [2000],
#        [2000],
#        [2000],
#        [2000],
#        [2000],
#        [2000],
#        [2000],
#        [1999],
#        [1999],
#        [1999],
#        [1999],
#        [1999],
#        [1999],
#        [1999],
#        [1999],
#        [1999],
#        [1998],
#        [1998],
#        [1998],
#        [1998],
#        [1998],
#        [1998],
#        [1998],
#        [1998],
#        [1998],
#        [1997],
#        [1997],
#        [1997],
#        [1997],
#        [1997],
#        [1997],
#        [1997],
#        [1997],
#        [1997],
#        [1996],
#        [1996],
#        [1996],
#        [1996],
#        [1996],
#        [1996],
#        [1996],
#        [1996],
#        [1996],
#        [1995],
#        [1995],
#        [1995],
#        [1995],
#        [1995],
#        [1995],
#        [1995],
#        [1995],
#        [1995],
#        [1994],
#        [1994],
#        [1994],
#        [1994],
#        [1994],
#        [1994],
#        [1994],
#        [1994],
#        [1994],
#        [1993],
#        [1993],
#        [1993],
#        [1993],
#        [1993],
#        [1993],
#        [1993],
#        [1993],
#        [1993],
#        [1992],
#        [1992],
#        [1992],
#        [1992],
#        [1992],
#        [1992],
#        [1992],
#        [1992],
#        [1992],
#        [1991],
#        [1991],
#        [1991],
#        [1991],
#        [1991],
#        [1991],
#        [1991],
#        [1991],
#        [1991],
#        [1990],
#        [1990],
#        [1990],
#        [1990],
#        [1990],
#        [1990],
#        [1990],
#        [1990],
#        [1990],
#        [1989],
#        [1989],
#        [1989],
#        [1989],
#        [1989],
#        [1989],
#        [1989],
#        [1989],
#        [1989],
#        [1988],
#        [1988],
#        [1988],
#        [1988],
#        [1988],
#        [1988],
#        [1988],
#        [1988],
#        [1988]], dtype=int64)

# %%
plt.scatter(X, y)
  # from Stackoverflow-- "Your variable  probably has the wrong shape"

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[-45.33604427]]
# y-axis intercept:  [92392.95122797]

# %%
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1988]]
# Max X Value: [[2020]]

# %%
plt.scatter(X, y, c='blue')
plt.plot([x_min[1], x_max[0]], [y_min[0], y_max[0]], c='red')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-1b987de7b58b> in <module>
#       1 plt.scatter(X, y, c='blue')
# ----> 2 plt.plot([x_min[1], x_max[0]], [y_min[0], y_max[0]], c='red')
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
import pandas as pd
from pycaret.regression import *

# %%
df = pd.read_csv('Brazilsimpledata.csv')

# %%
df.shape
# Out:
# (31, 4)

# %%
df_drop = df.dropna()

# %%
df_drop
# Out:
#     Year  Percentage of land  Area  Area combined
# 0   1990           70.458021   730           1680
# 1   1991           70.005654    30           1730
# 2   1992           69.553288   786           1861
# 3   1993           69.100922   896           1099
# 4   1994           68.648556   896           1099
# 5   1995           68.196190    59           3033
# 6   1996           67.743823   161           1194
# 7   1997           67.291457   227           1396
# 8   1998           66.839091   383           1348
# 9   1999           66.386725   259           1662
# 10  2000           65.934359   226           1570
# 11  2001           65.461671   165           1613
# 12  2002           64.988983   650           1586
# 13  2003           64.516295   396           1783
# 14  2004           64.043608   772           2774
# 15  2005           63.570920    14           1288
# 16  2006           63.098232   286           1041
# 17  2007           62.625545   651           1815
# ...

# %%
reg1 = setup(data=df_drop, target = 'Percentage of land',numeric_features = ['Area','Area combined'], session_id=123)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            20:54:39
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                     Data Type
# Year                ID Column
# Area                  Numeric
# Area combined         Numeric
# Percentage of land      Label
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-804578b5ed29> in <module>
# ----> 1 reg1 = setup(data=df_drop, target = 'Percentage of land',numeric_features = ['Area','Area combined'], session_id=123)
#
# ...

# %%
Xdf.info()

# %%
import pandas as pd
import zipfile

# %%
df = pd.read_csv('archive.zip',compression='zip')

# %%
df.head()
# Out:
#       Entity Code  Year  Net forest conversion
# 0    Algeria  DZA  1990                -8800.0
# 1    Algeria  DZA  2000                33900.0
# 2    Algeria  DZA  2010                 7600.0
# 3    Algeria  DZA  2015                -1400.0
# 4  Argentina  ARG  1990              -182600.0

# %%
df_col = df['Entity'].unique()
print(df_col)
# Out:
# ['Algeria' 'Argentina' 'Aruba' 'Australia' 'Austria' 'Azerbaijan'
#  'Bahrain' 'Bangladesh' 'Belarus' 'Belgium' 'Belize' 'Bhutan' 'Bolivia'
#  'Brazil' 'Bulgaria' 'Burundi' 'Cameroon' 'Canada' 'Cape Verde'
#  'Cayman Islands' 'Central African Republic' 'Chile' 'China' 'Colombia'
#  'Congo' 'Costa Rica' 'Croatia' 'Cuba' 'Denmark' 'Djibouti'
#  'Dominican Republic' 'Ecuador' 'El Salvador' 'Equatorial Guinea'
#  'Estonia' 'Ethiopia' 'Falkland Islands' 'Faroe Islands' 'Finland'
#  'French Guyana' 'Gabon' 'Georgia' 'Germany' 'Gibraltar' 'Greenland'
#  'Guadeloupe' 'Guatemala' 'Guinea' 'Guyana' 'Honduras' 'Hungary' 'Iceland'
#  'India' 'Indonesia' 'Iraq' 'Ireland' 'Isle of Man' 'Italy' 'Jamaica'
#  'Kuwait' 'Kyrgyzstan' 'Latvia' 'Liberia' 'Liechtenstein' 'Lithuania'
#  'Madagascar' 'Malawi' 'Maldives' 'Mali' 'Martinique' 'Mauritania'
#  'Mauritius' 'Mayotte' 'Mexico' 'Moldova' 'Monaco' 'Mongolia' 'Montenegro'
#  'Morocco' 'Mozambique' 'Myanmar' 'Nauru' 'Nepal' 'Netherlands'
# ...

# %%
s_a_df = df[df['Entity'].isin(['Argentina','Bolivia','Brazil','Chile','Colombia','Ecuador','Guyana','Paraguay','Peru','Suriname','Uruguay','Venezuela','French Guyana'])]
s_a_df
# Out:
#             Entity Code  Year  Net forest conversion
# 4        Argentina  ARG  1990              -182600.0
# 5        Argentina  ARG  2000              -316400.0
# 6        Argentina  ARG  2010              -223400.0
# 7        Argentina  ARG  2015              -104800.0
# 42         Bolivia  BOL  1990              -270330.0
# 43         Bolivia  BOL  2000              -201540.0
# 44         Bolivia  BOL  2010              -211760.0
# 45         Bolivia  BOL  2015              -238690.0
# 46          Brazil  BRA  1990             -3780940.0
# 47          Brazil  BRA  2000             -3950790.0
# 48          Brazil  BRA  2010             -1539180.0
# 49          Brazil  BRA  2015             -1453040.0
# 77           Chile  CHL  1990                57100.0
# 78           Chile  CHL  2000                90820.0
# 79           Chile  CHL  2010               174160.0
# 80           Chile  CHL  2015               122920.0
# 85        Colombia  COL  1990              -222260.0
# ...

# %%
s_a_df.to_csv('s_a.csv')

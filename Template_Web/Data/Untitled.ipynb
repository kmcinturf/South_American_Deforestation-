# %%
import pandas as pd

# %%
blue_data = pd.read_csv("Blue_whales_North.csv")

# %%
blue1 = blue_data[blue_data["individualID"].str.contains("2005CA-Bmu-01390")]
print(len(blue1))
# Out:
# 285

# %%
blue2 = blue_data[blue_data["individualID"].str.contains("2005CA-Bmu-02082")]
print(len(blue2))
# Out:
# 26

# %%
blue3 = blue_data[blue_data["individualID"].str.contains("2005CA-Bmu-00845")]
print(len(blue3))
# Out:
# 46

# %%
blue4 = blue_data[blue_data["individualID"].str.contains("2005CA-Bmu-01388")]
print(len(blue4))
# Out:
# 75

# %%
all_blue = [blue1, blue2, blue3, blue4]

# %%
blue_whale_124 = pd.concat(all_blue)
blue_whale_124
# Out:
#         event-id  visible timestamp     long     lat  argos:best-level  \
# 94    9018011315     True   12:00.0 -122.015  36.668               NaN
# 8679  9018020238     True   20:36.0 -122.032  36.657            -136.0
# 8680  9018020239     True   52:41.0 -121.947  36.707            -133.0
# 8681  9018020240     True   59:26.0 -122.406  36.715            -128.0
# 8682  9018020241    False   17:08.0 -121.766  36.809            -130.0
# ...          ...      ...       ...      ...     ...               ...
# 8549  9018020108     True   55:40.0 -122.563  35.198            -134.0
# 8550  9018020109     True   59:31.0 -123.653  35.355            -129.0
# 8551  9018020110     True   01:50.0 -122.310  35.234            -134.0
# 8552  9018020111     True   50:31.0 -122.307  35.315            -129.0
# 8553  9018020112     True   03:35.0 -121.931  35.357            -129.0
#
#       argos:calcul-freq  argos:iq  argos:lat1  argos:lat2  ... argos:lon1  \
# ...

# %%
blue_whale_124.to_csv(r'Blue_whale.csv', index = False, header = True)
